# %%
from tqdm.notebook import tqdm
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import matplotlib.font_manager as fm

font_name = fm.FontProperties(fname=r"C:\Windows\Fonts\malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import time
import random
from tqdm import tqdm_notebook

import folium
from IPython.display import display

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import os
import traceback

from sklearn.linear_model import LinearRegression

# %%
tot_items = pd.read_excel("C:\\juna27\\Git\\data\\data1\\품목별_소비자물가지수_품목성질별_2020100__20230425170328(품목별_기본_시도별).xlsx")
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
tot_items
# Out:
#             시도별    시점    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스  \
# 0      　　　서울특별시  2012   84.572   94.385       116.948   85.828   96.900
# 1      　　　서울특별시  2013   83.128   95.505       122.581   88.279   97.600
# 2      　　　서울특별시  2014   80.868   97.119       127.783   90.754   98.230
# 3      　　　서울특별시  2015   83.425   97.842       116.394   93.574   99.893
# 4      　　　서울특별시  2016   86.541   97.718       103.955   95.904  101.421
# ..          ...   ...      ...      ...           ...      ...      ...
# 171  　　　제주특별자치도  2018   94.969  101.055        99.231  100.625  100.639
# 172  　　　제주특별자치도  2019   94.868  100.738        99.392  100.387  100.001
# 173  　　　제주특별자치도  2020  100.000  100.000       100.000  100.000  100.000
# 174  　　　제주특별자치도  2021  108.940  103.160        99.360  100.010  100.710
# 175  　　　제주특별자치도  2022  114.180  111.430       109.410  101.010  101.810
#
#        개인서비스
# 0     85.290
# 1     86.444
# 2     87.971
# 3     89.690
# 4     92.102
# ..       ...
# ...

# %%
# birth_rate = [1.30, 1.19, 1.21, 1.24, 1.17, 1.05, 0.98, 0.92, 0.84, 0.81, 0.78]

# %%
# tot_items["출산율"] = birth_rate

# %%
tot_items
# Out:
#             시도별    시점    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스  \
# 0      　　　서울특별시  2012   84.572   94.385       116.948   85.828   96.900
# 1      　　　서울특별시  2013   83.128   95.505       122.581   88.279   97.600
# 2      　　　서울특별시  2014   80.868   97.119       127.783   90.754   98.230
# 3      　　　서울특별시  2015   83.425   97.842       116.394   93.574   99.893
# 4      　　　서울특별시  2016   86.541   97.718       103.955   95.904  101.421
# ..          ...   ...      ...      ...           ...      ...      ...
# 171  　　　제주특별자치도  2018   94.969  101.055        99.231  100.625  100.639
# 172  　　　제주특별자치도  2019   94.868  100.738        99.392  100.387  100.001
# 173  　　　제주특별자치도  2020  100.000  100.000       100.000  100.000  100.000
# 174  　　　제주특별자치도  2021  108.940  103.160        99.360  100.010  100.710
# 175  　　　제주특별자치도  2022  114.180  111.430       109.410  101.010  101.810
#
#        개인서비스
# 0     85.290
# 1     86.444
# 2     87.971
# 3     89.690
# 4     92.102
# ..       ...
# ...

# %%
tot_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   시도별           176 non-null    object
#  1   시점            176 non-null    int64
#  2   농축수산물         176 non-null    float64
#  3   공업제품          176 non-null    float64
#  4   전기 · 가스 · 수도  176 non-null    float64
#  5   집세            176 non-null    float64
#  6   공공서비스         176 non-null    float64
#  7   개인서비스         176 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
tot_items.set_index("시점", inplace=True)

# %%
tot_items
# Out:
#              시도별    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스    개인서비스
# 시점
# 2012    　　　서울특별시   84.572   94.385       116.948   85.828   96.900   85.290
# 2013    　　　서울특별시   83.128   95.505       122.581   88.279   97.600   86.444
# 2014    　　　서울특별시   80.868   97.119       127.783   90.754   98.230   87.971
# 2015    　　　서울특별시   83.425   97.842       116.394   93.574   99.893   89.690
# 2016    　　　서울특별시   86.541   97.718       103.955   95.904  101.421   92.102
# ...          ...      ...      ...           ...      ...      ...      ...
# 2018  　　　제주특별자치도   94.969  101.055        99.231  100.625  100.639   97.601
# 2019  　　　제주특별자치도   94.868  100.738        99.392  100.387  100.001   99.235
# 2020  　　　제주특별자치도  100.000  100.000       100.000  100.000  100.000  100.000
# 2021  　　　제주특별자치도  108.940  103.160        99.360  100.010  100.710  101.950
# 2022  　　　제주특별자치도  114.180  111.430       109.410  101.010  101.810  108.670
#
# [176 rows x 7 columns]

# %%
birth_rate = [1.30, 1.19, 1.21, 1.24, 1.17, 1.05, 0.98, 0.92, 0.84, 0.81, 0.78]
birth_rate = np.tile(birth_rate, 16)
tot_items["출산율"] = birth_rate

# %%
tot_items.head(33)
# Out:
#            시도별    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스    개인서비스  \
# 시점
# 2012  　　　서울특별시   84.572   94.385       116.948   85.828   96.900   85.290
# 2013  　　　서울특별시   83.128   95.505       122.581   88.279   97.600   86.444
# 2014  　　　서울특별시   80.868   97.119       127.783   90.754   98.230   87.971
# 2015  　　　서울특별시   83.425   97.842       116.394   93.574   99.893   89.690
# 2016  　　　서울특별시   86.541   97.718       103.955   95.904  101.421   92.102
# 2017  　　　서울특별시   92.974   98.660       102.933   97.917  102.209   94.468
# 2018  　　　서울특별시   95.673   99.578        99.726   98.935  102.459   96.953
# 2019  　　　서울특별시   92.937   99.897       101.541   99.258  102.442   98.815
# 2020  　　　서울특별시  100.000  100.000       100.000  100.000  100.000  100.000
# 2021  　　　서울특별시  107.860  101.510        97.660  101.610  100.800  102.510
# 2022  　　　서울특별시  111.670  107.430       112.300  103.350  101.510  108.110
# 2012  　　　부산광역시   86.980   94.925       111.049   93.777   98.489   84.264
# ...

# %%
tot_items
# Out:
#              시도별    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스    개인서비스  \
# 시점
# 2012    　　　서울특별시   84.572   94.385       116.948   85.828   96.900   85.290
# 2013    　　　서울특별시   83.128   95.505       122.581   88.279   97.600   86.444
# 2014    　　　서울특별시   80.868   97.119       127.783   90.754   98.230   87.971
# 2015    　　　서울특별시   83.425   97.842       116.394   93.574   99.893   89.690
# 2016    　　　서울특별시   86.541   97.718       103.955   95.904  101.421   92.102
# ...          ...      ...      ...           ...      ...      ...      ...
# 2018  　　　제주특별자치도   94.969  101.055        99.231  100.625  100.639   97.601
# 2019  　　　제주특별자치도   94.868  100.738        99.392  100.387  100.001   99.235
# 2020  　　　제주특별자치도  100.000  100.000       100.000  100.000  100.000  100.000
# 2021  　　　제주특별자치도  108.940  103.160        99.360  100.010  100.710  101.950
# 2022  　　　제주특별자치도  114.180  111.430       109.410  101.010  101.810  108.670
#
#        출산율
# 시점
# 2012  1.30
# 2013  1.19
# ...

# %%
# 엑셀 or csv 파일로 저장

# %%
tot_items.to_csv("C:/juna27/Git/data/data1/물가지수(품목별).csv",index = True, encoding="EUC-KR")

# %%
tot_items_eatout = pd.read_excel("C:\\juna27\\Git\\data\\data1\\품목별_소비자물가지수_품목성질별_2020100__20230425174759(품목별_외식구분_시도별).xlsx")
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
tot_items_eatout
# Out:
#             시도별    시점    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스  \
# 0      　　　서울특별시  2012   84.572   94.385       116.948   85.828   96.900
# 1      　　　서울특별시  2013   83.128   95.505       122.581   88.279   97.600
# 2      　　　서울특별시  2014   80.868   97.119       127.783   90.754   98.230
# 3      　　　서울특별시  2015   83.425   97.842       116.394   93.574   99.893
# 4      　　　서울특별시  2016   86.541   97.718       103.955   95.904  101.421
# ..          ...   ...      ...      ...           ...      ...      ...
# 171  　　　제주특별자치도  2018   94.969  101.055        99.231  100.625  100.639
# 172  　　　제주특별자치도  2019   94.868  100.738        99.392  100.387  100.001
# 173  　　　제주특별자치도  2020  100.000  100.000       100.000  100.000  100.000
# 174  　　　제주특별자치도  2021  108.940  103.160        99.360  100.010  100.710
# 175  　　　제주특별자치도  2022  114.180  111.430       109.410  101.010  101.810
#
#           외식     외식제외
# 0     84.725   85.643
# 1     85.781   86.860
# 2     86.827   88.683
# ...

# %%
# birth_rate = [1.30, 1.19, 1.21, 1.24, 1.17, 1.05, 0.98, 0.92, 0.84, 0.81, 0.78]

# %%
# tot_items_eatout["출산율"] = birth_rate

# %%
tot_items_eatout
# Out:
#             시도별    시점    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스  \
# 0      　　　서울특별시  2012   84.572   94.385       116.948   85.828   96.900
# 1      　　　서울특별시  2013   83.128   95.505       122.581   88.279   97.600
# 2      　　　서울특별시  2014   80.868   97.119       127.783   90.754   98.230
# 3      　　　서울특별시  2015   83.425   97.842       116.394   93.574   99.893
# 4      　　　서울특별시  2016   86.541   97.718       103.955   95.904  101.421
# ..          ...   ...      ...      ...           ...      ...      ...
# 171  　　　제주특별자치도  2018   94.969  101.055        99.231  100.625  100.639
# 172  　　　제주특별자치도  2019   94.868  100.738        99.392  100.387  100.001
# 173  　　　제주특별자치도  2020  100.000  100.000       100.000  100.000  100.000
# 174  　　　제주특별자치도  2021  108.940  103.160        99.360  100.010  100.710
# 175  　　　제주특별자치도  2022  114.180  111.430       109.410  101.010  101.810
#
#           외식     외식제외
# 0     84.725   85.643
# 1     85.781   86.860
# 2     86.827   88.683
# ...

# %%
tot_items_eatout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   시도별           176 non-null    object
#  1   시점            176 non-null    int64
#  2   농축수산물         176 non-null    float64
#  3   공업제품          176 non-null    float64
#  4   전기 · 가스 · 수도  176 non-null    float64
#  5   집세            176 non-null    float64
#  6   공공서비스         176 non-null    float64
#  7   외식            176 non-null    float64
#  8   외식제외          176 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 12.5+ KB

# %%
tot_items_eatout.set_index("시점", inplace=True)

# %%
tot_items_eatout
# Out:
#              시도별    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스       외식  \
# 시점
# 2012    　　　서울특별시   84.572   94.385       116.948   85.828   96.900   84.725
# 2013    　　　서울특별시   83.128   95.505       122.581   88.279   97.600   85.781
# 2014    　　　서울특별시   80.868   97.119       127.783   90.754   98.230   86.827
# 2015    　　　서울특별시   83.425   97.842       116.394   93.574   99.893   89.258
# 2016    　　　서울특별시   86.541   97.718       103.955   95.904  101.421   91.724
# ...          ...      ...      ...           ...      ...      ...      ...
# 2018  　　　제주특별자치도   94.969  101.055        99.231  100.625  100.639   97.823
# 2019  　　　제주특별자치도   94.868  100.738        99.392  100.387  100.001   98.896
# 2020  　　　제주특별자치도  100.000  100.000       100.000  100.000  100.000  100.000
# 2021  　　　제주특별자치도  108.940  103.160        99.360  100.010  100.710  103.040
# 2022  　　　제주특별자치도  114.180  111.430       109.410  101.010  101.810  111.030
#
#          외식제외
# 시점
# 2012   85.643
# 2013   86.860
# ...

# %%
birth_rate = [1.30, 1.19, 1.21, 1.24, 1.17, 1.05, 0.98, 0.92, 0.84, 0.81, 0.78]
birth_rate = np.tile(birth_rate, 16)
tot_items_eatout["출산율"] = birth_rate

# %%
tot_items_eatout.head(33)
# Out:
#            시도별    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스       외식  \
# 시점
# 2012  　　　서울특별시   84.572   94.385       116.948   85.828   96.900   84.725
# 2013  　　　서울특별시   83.128   95.505       122.581   88.279   97.600   85.781
# 2014  　　　서울특별시   80.868   97.119       127.783   90.754   98.230   86.827
# 2015  　　　서울특별시   83.425   97.842       116.394   93.574   99.893   89.258
# 2016  　　　서울특별시   86.541   97.718       103.955   95.904  101.421   91.724
# 2017  　　　서울특별시   92.974   98.660       102.933   97.917  102.209   93.998
# 2018  　　　서울특별시   95.673   99.578        99.726   98.935  102.459   97.070
# 2019  　　　서울특별시   92.937   99.897       101.541   99.258  102.442   99.216
# 2020  　　　서울특별시  100.000  100.000       100.000  100.000  100.000  100.000
# 2021  　　　서울특별시  107.860  101.510        97.660  101.610  100.800  102.820
# 2022  　　　서울특별시  111.670  107.430       112.300  103.350  101.510  110.560
# 2012  　　　부산광역시   86.980   94.925       111.049   93.777   98.489   85.107
# ...

# %%
tot_items_eatout
# Out:
#              시도별    농축수산물     공업제품  전기 · 가스 · 수도       집세    공공서비스       외식  \
# 시점
# 2012    　　　서울특별시   84.572   94.385       116.948   85.828   96.900   84.725
# 2013    　　　서울특별시   83.128   95.505       122.581   88.279   97.600   85.781
# 2014    　　　서울특별시   80.868   97.119       127.783   90.754   98.230   86.827
# 2015    　　　서울특별시   83.425   97.842       116.394   93.574   99.893   89.258
# 2016    　　　서울특별시   86.541   97.718       103.955   95.904  101.421   91.724
# ...          ...      ...      ...           ...      ...      ...      ...
# 2018  　　　제주특별자치도   94.969  101.055        99.231  100.625  100.639   97.823
# 2019  　　　제주특별자치도   94.868  100.738        99.392  100.387  100.001   98.896
# 2020  　　　제주특별자치도  100.000  100.000       100.000  100.000  100.000  100.000
# 2021  　　　제주특별자치도  108.940  103.160        99.360  100.010  100.710  103.040
# 2022  　　　제주특별자치도  114.180  111.430       109.410  101.010  101.810  111.030
#
#          외식제외   출산율
# 시점
# 2012   85.643  1.30
# ...

# %%
# 엑셀 or csv 파일로 저장

# %%
tot_items_eatout.to_csv("C:/juna27/Git/data/data1/물가지수(품목별_외식).csv",index = True, encoding="EUC-KR")

# %% [markdown]
# # ----------------------------------------

# %%
item_ext = pd.read_excel("C:\\juna27\\Git\\data\\data1\\품목별_소비자물가지수_품목성질별_2020100__20230425190026(물가지수_단어추출_행렬전환).xlsx")

# %%
item_ext.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 48 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시도별         176 non-null    object
#  1   시점          176 non-null    int64
#  2   분유          176 non-null    float64
#  3   이유식         176 non-null    float64
#  4   TV          176 non-null    float64
#  5   영상음향기기      176 non-null    float64
#  6   휴대용멀티미디어기기  176 non-null    float64
#  7   악기          176 non-null    float64
#  8   유아동복        176 non-null    float64
#  9   유아용학습교재     176 non-null    float64
#  10  초등학교학습서     176 non-null    float64
#  11  중학교학습서      176 non-null    float64
#  12  고등학교학습서     176 non-null    float64
#  13  아동화         176 non-null    float64
#  14  장난감         176 non-null    float64
#  15  반려동물용품      176 non-null    float64
#  16  종이문구        176 non-null    float64
#  17  기타문구        176 non-null    float64
# ...

# %%
# item_ext_t = item_ext.T

# %%
# item_ext_t_drop = item_ext_t.dropna()

# %%
# item_ext = item_ext_t_drop.T

# %%
item_ext
# Out:
#             시도별    시점       분유      이유식       TV   영상음향기기  휴대용멀티미디어기기  \
# 0      　　　서울특별시  2012   98.660   95.056  202.849   98.947      94.083
# 1      　　　서울특별시  2013   98.974   95.798  191.743  106.726      92.560
# 2      　　　서울특별시  2014  106.709   96.081  175.617  105.715      92.888
# 3      　　　서울특별시  2015  111.558   98.969  157.692  105.991      88.127
# 4      　　　서울특별시  2016  102.943   97.386  143.824  106.690      91.959
# ..          ...   ...      ...      ...      ...      ...         ...
# 171  　　　제주특별자치도  2018   92.552   91.736  117.371  102.351     101.444
# 172  　　　제주특별자치도  2019   93.515   97.821  108.932  100.064     102.703
# 173  　　　제주특별자치도  2020  100.000  100.000  100.000  100.000     100.000
# 174  　　　제주특별자치도  2021  103.910  100.000   97.820   98.130      99.070
# 175  　　　제주특별자치도  2022  103.630  100.150   96.030   99.450     100.510
#
#           악기     유아동복  유아용학습교재  ...    운동학원비    전산학원비    가정학습지   이러닝이용료  \
# ...

# %%
# birth_rate = [1.30, 1.19, 1.21, 1.24, 1.17, 1.05, 0.98, 0.92, 0.84, 0.81, 0.78]

# %%
# item_ext["출산율"] = birth_rate

# %%
item_ext
# Out:
#             시도별    시점       분유      이유식       TV   영상음향기기  휴대용멀티미디어기기  \
# 0      　　　서울특별시  2012   98.660   95.056  202.849   98.947      94.083
# 1      　　　서울특별시  2013   98.974   95.798  191.743  106.726      92.560
# 2      　　　서울특별시  2014  106.709   96.081  175.617  105.715      92.888
# 3      　　　서울특별시  2015  111.558   98.969  157.692  105.991      88.127
# 4      　　　서울특별시  2016  102.943   97.386  143.824  106.690      91.959
# ..          ...   ...      ...      ...      ...      ...         ...
# 171  　　　제주특별자치도  2018   92.552   91.736  117.371  102.351     101.444
# 172  　　　제주특별자치도  2019   93.515   97.821  108.932  100.064     102.703
# 173  　　　제주특별자치도  2020  100.000  100.000  100.000  100.000     100.000
# 174  　　　제주특별자치도  2021  103.910  100.000   97.820   98.130      99.070
# 175  　　　제주특별자치도  2022  103.630  100.150   96.030   99.450     100.510
#
#           악기     유아동복  유아용학습교재  ...    운동학원비    전산학원비    가정학습지   이러닝이용료  \
# ...

# %%
item_ext.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 48 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시도별         176 non-null    object
#  1   시점          176 non-null    int64
#  2   분유          176 non-null    float64
#  3   이유식         176 non-null    float64
#  4   TV          176 non-null    float64
#  5   영상음향기기      176 non-null    float64
#  6   휴대용멀티미디어기기  176 non-null    float64
#  7   악기          176 non-null    float64
#  8   유아동복        176 non-null    float64
#  9   유아용학습교재     176 non-null    float64
#  10  초등학교학습서     176 non-null    float64
#  11  중학교학습서      176 non-null    float64
#  12  고등학교학습서     176 non-null    float64
#  13  아동화         176 non-null    float64
#  14  장난감         176 non-null    float64
#  15  반려동물용품      176 non-null    float64
#  16  종이문구        176 non-null    float64
#  17  기타문구        176 non-null    float64
# ...

# %%
item_ext.set_index("시점", inplace=True)

# %%
item_ext
# Out:
#              시도별       분유      이유식       TV   영상음향기기  휴대용멀티미디어기기       악기  \
# 시점
# 2012    　　　서울특별시   98.660   95.056  202.849   98.947      94.083   90.331
# 2013    　　　서울특별시   98.974   95.798  191.743  106.726      92.560   93.632
# 2014    　　　서울특별시  106.709   96.081  175.617  105.715      92.888   92.388
# 2015    　　　서울특별시  111.558   98.969  157.692  105.991      88.127   91.936
# 2016    　　　서울특별시  102.943   97.386  143.824  106.690      91.959   91.157
# ...          ...      ...      ...      ...      ...         ...      ...
# 2018  　　　제주특별자치도   92.552   91.736  117.371  102.351     101.444   99.655
# 2019  　　　제주특별자치도   93.515   97.821  108.932  100.064     102.703   99.800
# 2020  　　　제주특별자치도  100.000  100.000  100.000  100.000     100.000  100.000
# 2021  　　　제주특별자치도  103.910  100.000   97.820   98.130      99.070  100.340
# 2022  　　　제주특별자치도  103.630  100.150   96.030   99.450     100.510  102.640
#
#          유아동복  유아용학습교재  초등학교학습서  ...    운동학원비    전산학원비    가정학습지   이러닝이용료  \
# ...

# %%
birth_rate = [1.30, 1.19, 1.21, 1.24, 1.17, 1.05, 0.98, 0.92, 0.84, 0.81, 0.78]
birth_rate = np.tile(birth_rate, 16)
item_ext["출산율"] = birth_rate

# %%
item_ext.head(33)
# Out:
#            시도별       분유      이유식       TV   영상음향기기  휴대용멀티미디어기기       악기  \
# 시점
# 2012  　　　서울특별시   98.660   95.056  202.849   98.947      94.083   90.331
# 2013  　　　서울특별시   98.974   95.798  191.743  106.726      92.560   93.632
# 2014  　　　서울특별시  106.709   96.081  175.617  105.715      92.888   92.388
# 2015  　　　서울특별시  111.558   98.969  157.692  105.991      88.127   91.936
# 2016  　　　서울특별시  102.943   97.386  143.824  106.690      91.959   91.157
# 2017  　　　서울특별시  101.063   98.899  131.350  103.983      97.070   94.130
# 2018  　　　서울특별시   97.666   91.736  117.371  100.991     101.444   97.044
# 2019  　　　서울특별시   97.033   97.821  108.932  100.197     102.703   99.380
# 2020  　　　서울특별시  100.000  100.000  100.000  100.000     100.000  100.000
# 2021  　　　서울특별시  100.410  100.000   97.820   96.930      99.070  101.820
# 2022  　　　서울특별시  101.970  100.150   96.030   99.250     100.510  104.630
# 2012  　　　부산광역시   95.729   95.640  213.119   98.780     102.180   97.066
# ...

# %%
item_ext
# Out:
#              시도별       분유      이유식       TV   영상음향기기  휴대용멀티미디어기기       악기  \
# 시점
# 2012    　　　서울특별시   98.660   95.056  202.849   98.947      94.083   90.331
# 2013    　　　서울특별시   98.974   95.798  191.743  106.726      92.560   93.632
# 2014    　　　서울특별시  106.709   96.081  175.617  105.715      92.888   92.388
# 2015    　　　서울특별시  111.558   98.969  157.692  105.991      88.127   91.936
# 2016    　　　서울특별시  102.943   97.386  143.824  106.690      91.959   91.157
# ...          ...      ...      ...      ...      ...         ...      ...
# 2018  　　　제주특별자치도   92.552   91.736  117.371  102.351     101.444   99.655
# 2019  　　　제주특별자치도   93.515   97.821  108.932  100.064     102.703   99.800
# 2020  　　　제주특별자치도  100.000  100.000  100.000  100.000     100.000  100.000
# 2021  　　　제주특별자치도  103.910  100.000   97.820   98.130      99.070  100.340
# 2022  　　　제주특별자치도  103.630  100.150   96.030   99.450     100.510  102.640
#
#          유아동복  유아용학습교재  초등학교학습서  ...    전산학원비    가정학습지   이러닝이용료  학교보충교육비  \
# ...

# %%
# 엑셀 or csv 파일로 저장

# %%
item_ext.to_csv("C:/juna27/Git/data/data1/물가지수(단어_추출).csv",index = True, encoding="EUC-KR")
